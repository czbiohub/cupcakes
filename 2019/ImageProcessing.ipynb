# %% [markdown]
# # Python for Basic Image Processing

# %% [markdown]
# ## What is a Jupyter Notebook
# #### Jupyter is an acronym for Julia + Python + R, the initial languages the programming supported, but now supports many more language.
# #### The notebook contains documents for computer code (supported by a variety of languages) and rich text, e.g. paragraphs and figures.

# %% [markdown]
# ## Useful Terms
# #### String:
# #### Array:
# #### Library:
#
# ## Jupyter specific terms
# #### Cell: where you enter and run your code
# #### Kernel: the "computational engine" that executes code in a specific language, e.g. Python 3

# %% [markdown]
# ## Importing useful libraries

# %%
import matplotlib.pyplot as plt
import matplotlib

import numpy as np

import skimage

from skimage import data
from skimage import exposure

# %% [markdown]
# ## Defining and reading an image path

# %%
path = '/Users/liennachan/Documents/'
img = skimage.io.imread(path + 'example_img.tif')

# %% [markdown]
# ## Showing an image

# %%
plt.imshow(img)

# %% [markdown]
# ## Colormapping

# %%
plt.imshow(img, cmap = 'gray')

# %%
plt.imshow(img, cmap = 'nipy_spectral')

# %%
plt.imshow(img, cmap = 'plasma')

# %%
plt.imshow(img, cmap = 'Accent')

# %%
#reversing a colormap
plt.imshow(img, cmap = 'Accent_r')

# %%
plt.hist(img.ravel())
# Out:
# (array([2.270000e+03, 1.322200e+04, 6.226600e+04, 2.985010e+05,
#         3.024541e+06, 6.232790e+05, 1.433000e+05, 2.371500e+04,
#         3.093000e+03, 1.170000e+02]),
#  array([12043. , 15951.4, 19859.8, 23768.2, 27676.6, 31585. , 35493.4,
#         39401.8, 43310.2, 47218.6, 51127. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(img.ravel(), bins=100)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.imshow(img, clim=(25000, 35000), cmap = 'gray')
